# %%
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Preprocessing: wavelet transform as a feature for traning the model

# %%
import numpy as np
import pywt
import cv2
img = cv2.imread('./test_images/mason_mount (2).jpg')
img.shape
# Out:
# (872, 1023, 3)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (872, 1023)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[325, 171, 321, 321]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
plt.imshow(roi_color, cmap='gray')
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (321, 321, 3)

# %% [markdown]
# Wavelength Transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
Load Image

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/mason_mount (2).jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/mason_mount (2).jpg')
plt.imshow(cropped_image)

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped',
#  './dataset/marco_reus',
#  './dataset/mason_mount',
#  './dataset/ronaldo',
#  './dataset/sergio_ramos',
#  './dataset/toni_kroos']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/marco_reus
# Generating cropped images in folder:  ./dataset/cropped/mason_mount
# Generating cropped images in folder:  ./dataset/cropped/ronaldo
# Generating cropped images in folder:  ./dataset/cropped/sergio_ramos
# Generating cropped images in folder:  ./dataset/cropped/toni_kroos

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'marco_reus': ['./dataset/cropped/marco_reus\\marco_reus1.png',
#   './dataset/cropped/marco_reus\\marco_reus10.png',
#   './dataset/cropped/marco_reus\\marco_reus11.png',
#   './dataset/cropped/marco_reus\\marco_reus12.png',
#   './dataset/cropped/marco_reus\\marco_reus13.png',
#   './dataset/cropped/marco_reus\\marco_reus14.png',
#   './dataset/cropped/marco_reus\\marco_reus15.png',
#   './dataset/cropped/marco_reus\\marco_reus16.png',
#   './dataset/cropped/marco_reus\\marco_reus17.png',
#   './dataset/cropped/marco_reus\\marco_reus18.png',
#   './dataset/cropped/marco_reus\\marco_reus19.png',
#   './dataset/cropped/marco_reus\\marco_reus2.png',
#   './dataset/cropped/marco_reus\\marco_reus20.png',
#   './dataset/cropped/marco_reus\\marco_reus21.png',
#   './dataset/cropped/marco_reus\\marco_reus22.png',
#   './dataset/cropped/marco_reus\\marco_reus23.png',
#   './dataset/cropped/marco_reus\\marco_reus24.png',
#   './dataset/cropped/marco_reus\\marco_reus25.png',
#   './dataset/cropped/marco_reus\\marco_reus26.png',
#   './dataset/cropped/marco_reus\\marco_reus27.png',
#   './dataset/cropped/marco_reus\\marco_reus28.png',
#   './dataset/cropped/marco_reus\\marco_reus29.png',
#   './dataset/cropped/marco_reus\\marco_reus3.png',
#   './dataset/cropped/marco_reus\\marco_reus30.png',
#   './dataset/cropped/marco_reus\\marco_reus31.png',
#   './dataset/cropped/marco_reus\\marco_reus32.png',
#   './dataset/cropped/marco_reus\\marco_reus33.png',
#   './dataset/cropped/marco_reus\\marco_reus34.png',
#   './dataset/cropped/marco_reus\\marco_reus35.png',
#   './dataset/cropped/marco_reus\\marco_reus36.png',
#   './dataset/cropped/marco_reus\\marco_reus37.png',
#   './dataset/cropped/marco_reus\\marco_reus38.png',
#   './dataset/cropped/marco_reus\\marco_reus39.png',
#   './dataset/cropped/marco_reus\\marco_reus4.png',
#   './dataset/cropped/marco_reus\\marco_reus40.png',
#   './dataset/cropped/marco_reus\\marco_reus41.png',
#   './dataset/cropped/marco_reus\\marco_reus42.png',
#   './dataset/cropped/marco_reus\\marco_reus43.png',
#   './dataset/cropped/marco_reus\\marco_reus44.png',
#   './dataset/cropped/marco_reus\\marco_reus45.png',
#   './dataset/cropped/marco_reus\\marco_reus46.png',
#   './dataset/cropped/marco_reus\\marco_reus47.png',
#   './dataset/cropped/marco_reus\\marco_reus48.png',
#   './dataset/cropped/marco_reus\\marco_reus5.png',
#   './dataset/cropped/marco_reus\\marco_reus6.png',
#   './dataset/cropped/marco_reus\\marco_reus7.png',
#   './dataset/cropped/marco_reus\\marco_reus8.png',
#   './dataset/cropped/marco_reus\\marco_reus9.png'],
#  'mason_mount': ['./dataset/cropped/mason_mount\\mason_mount1.png',
#   './dataset/cropped/mason_mount\\mason_mount10.png',
#   './dataset/cropped/mason_mount\\mason_mount11.png',
#   './dataset/cropped/mason_mount\\mason_mount12.png',
#   './dataset/cropped/mason_mount\\mason_mount13.png',
#   './dataset/cropped/mason_mount\\mason_mount14.png',
#   './dataset/cropped/mason_mount\\mason_mount15.png',
#   './dataset/cropped/mason_mount\\mason_mount16.png',
#   './dataset/cropped/mason_mount\\mason_mount17.png',
#   './dataset/cropped/mason_mount\\mason_mount18.png',
#   './dataset/cropped/mason_mount\\mason_mount19.png',
#   './dataset/cropped/mason_mount\\mason_mount2.png',
#   './dataset/cropped/mason_mount\\mason_mount20.png',
#   './dataset/cropped/mason_mount\\mason_mount21.png',
#   './dataset/cropped/mason_mount\\mason_mount22.png',
#   './dataset/cropped/mason_mount\\mason_mount23.png',
#   './dataset/cropped/mason_mount\\mason_mount24.png',
#   './dataset/cropped/mason_mount\\mason_mount25.png',
#   './dataset/cropped/mason_mount\\mason_mount26.png',
#   './dataset/cropped/mason_mount\\mason_mount27.png',
#   './dataset/cropped/mason_mount\\mason_mount28.png',
#   './dataset/cropped/mason_mount\\mason_mount29.png',
#   './dataset/cropped/mason_mount\\mason_mount3.png',
#   './dataset/cropped/mason_mount\\mason_mount30.png',
#   './dataset/cropped/mason_mount\\mason_mount31.png',
#   './dataset/cropped/mason_mount\\mason_mount32.png',
#   './dataset/cropped/mason_mount\\mason_mount33.png',
#   './dataset/cropped/mason_mount\\mason_mount34.png',
#   './dataset/cropped/mason_mount\\mason_mount35.png',
#   './dataset/cropped/mason_mount\\mason_mount36.png',
#   './dataset/cropped/mason_mount\\mason_mount37.png',
#   './dataset/cropped/mason_mount\\mason_mount38.png',
#   './dataset/cropped/mason_mount\\mason_mount39.png',
#   './dataset/cropped/mason_mount\\mason_mount4.png',
#   './dataset/cropped/mason_mount\\mason_mount40.png',
#   './dataset/cropped/mason_mount\\mason_mount41.png',
#   './dataset/cropped/mason_mount\\mason_mount42.png',
#   './dataset/cropped/mason_mount\\mason_mount43.png',
#   './dataset/cropped/mason_mount\\mason_mount5.png',
#   './dataset/cropped/mason_mount\\mason_mount6.png',
#   './dataset/cropped/mason_mount\\mason_mount7.png',
#   './dataset/cropped/mason_mount\\mason_mount8.png',
#   './dataset/cropped/mason_mount\\mason_mount9.png'],
#  'ronaldo': ['./dataset/cropped/ronaldo\\ronaldo1.png',
#   './dataset/cropped/ronaldo\\ronaldo10.png',
#   './dataset/cropped/ronaldo\\ronaldo11.png',
#   './dataset/cropped/ronaldo\\ronaldo12.png',
#   './dataset/cropped/ronaldo\\ronaldo13.png',
#   './dataset/cropped/ronaldo\\ronaldo14.png',
#   './dataset/cropped/ronaldo\\ronaldo15.png',
#   './dataset/cropped/ronaldo\\ronaldo16.png',
#   './dataset/cropped/ronaldo\\ronaldo17.png',
#   './dataset/cropped/ronaldo\\ronaldo18.png',
#   './dataset/cropped/ronaldo\\ronaldo19.png',
#   './dataset/cropped/ronaldo\\ronaldo2.png',
#   './dataset/cropped/ronaldo\\ronaldo20.png',
#   './dataset/cropped/ronaldo\\ronaldo21.png',
#   './dataset/cropped/ronaldo\\ronaldo22.png',
#   './dataset/cropped/ronaldo\\ronaldo23.png',
#   './dataset/cropped/ronaldo\\ronaldo24.png',
#   './dataset/cropped/ronaldo\\ronaldo25.png',
#   './dataset/cropped/ronaldo\\ronaldo26.png',
#   './dataset/cropped/ronaldo\\ronaldo3.png',
#   './dataset/cropped/ronaldo\\ronaldo4.png',
#   './dataset/cropped/ronaldo\\ronaldo5.png',
#   './dataset/cropped/ronaldo\\ronaldo6.png',
#   './dataset/cropped/ronaldo\\ronaldo7.png',
#   './dataset/cropped/ronaldo\\ronaldo8.png',
#   './dataset/cropped/ronaldo\\ronaldo9.png'],
#  'sergio_ramos': ['./dataset/cropped/sergio_ramos\\sergio_ramos1.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos10.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos11.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos12.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos13.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos14.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos15.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos16.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos17.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos18.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos19.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos2.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos20.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos21.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos22.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos23.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos24.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos25.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos26.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos27.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos28.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos29.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos3.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos30.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos4.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos5.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos6.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos7.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos8.png',
#   './dataset/cropped/sergio_ramos\\sergio_ramos9.png'],
#  'toni_kroos': ['./dataset/cropped/toni_kroos\\toni_kroos1.png',
#   './dataset/cropped/toni_kroos\\toni_kroos10.png',
#   './dataset/cropped/toni_kroos\\toni_kroos11.png',
#   './dataset/cropped/toni_kroos\\toni_kroos12.png',
#   './dataset/cropped/toni_kroos\\toni_kroos13.png',
#   './dataset/cropped/toni_kroos\\toni_kroos14.png',
#   './dataset/cropped/toni_kroos\\toni_kroos15.png',
#   './dataset/cropped/toni_kroos\\toni_kroos16.png',
#   './dataset/cropped/toni_kroos\\toni_kroos17.png',
#   './dataset/cropped/toni_kroos\\toni_kroos18.png',
#   './dataset/cropped/toni_kroos\\toni_kroos19.png',
#   './dataset/cropped/toni_kroos\\toni_kroos2.png',
#   './dataset/cropped/toni_kroos\\toni_kroos20.png',
#   './dataset/cropped/toni_kroos\\toni_kroos21.png',
#   './dataset/cropped/toni_kroos\\toni_kroos22.png',
#   './dataset/cropped/toni_kroos\\toni_kroos23.png',
#   './dataset/cropped/toni_kroos\\toni_kroos24.png',
#   './dataset/cropped/toni_kroos\\toni_kroos25.png',
#   './dataset/cropped/toni_kroos\\toni_kroos26.png',
#   './dataset/cropped/toni_kroos\\toni_kroos27.png',
#   './dataset/cropped/toni_kroos\\toni_kroos28.png',
#   './dataset/cropped/toni_kroos\\toni_kroos29.png',
#   './dataset/cropped/toni_kroos\\toni_kroos3.png',
#   './dataset/cropped/toni_kroos\\toni_kroos30.png',
#   './dataset/cropped/toni_kroos\\toni_kroos31.png',
#   './dataset/cropped/toni_kroos\\toni_kroos32.png',
#   './dataset/cropped/toni_kroos\\toni_kroos33.png',
#   './dataset/cropped/toni_kroos\\toni_kroos34.png',
#   './dataset/cropped/toni_kroos\\toni_kroos35.png',
#   './dataset/cropped/toni_kroos\\toni_kroos36.png',
#   './dataset/cropped/toni_kroos\\toni_kroos37.png',
#   './dataset/cropped/toni_kroos\\toni_kroos38.png',
#   './dataset/cropped/toni_kroos\\toni_kroos39.png',
#   './dataset/cropped/toni_kroos\\toni_kroos4.png',
#   './dataset/cropped/toni_kroos\\toni_kroos40.png',
#   './dataset/cropped/toni_kroos\\toni_kroos41.png',
#   './dataset/cropped/toni_kroos\\toni_kroos42.png',
#   './dataset/cropped/toni_kroos\\toni_kroos43.png',
#   './dataset/cropped/toni_kroos\\toni_kroos44.png',
#   './dataset/cropped/toni_kroos\\toni_kroos45.png',
#   './dataset/cropped/toni_kroos\\toni_kroos5.png',
#   './dataset/cropped/toni_kroos\\toni_kroos6.png',
#   './dataset/cropped/toni_kroos\\toni_kroos7.png',
#   './dataset/cropped/toni_kroos\\toni_kroos8.png',
#   './dataset/cropped/toni_kroos\\toni_kroos9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'marco_reus': 0,
#  'mason_mount': 1,
#  'ronaldo': 2,
#  'sergio_ramos': 3,
#  'toni_kroos': 4}

# %% [markdown]
# Model Training

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (192, 4096)

# %% [markdown]
# # Cleaning Done, Training

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.6458333333333334

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62        12
#            1       0.50      1.00      0.67         9
#            2       1.00      0.17      0.29         6
#            3       0.67      0.29      0.40         7
#            4       0.92      0.79      0.85        14
#
#     accuracy                           0.65        48
#    macro avg       0.73      0.58      0.56        48
# weighted avg       0.73      0.65      0.62        48

# %% [markdown]
# # GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.624877
# 1        random_forest    0.437931
# 2  logistic_regression    0.638424
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 5}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=5, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.7083333333333334

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5208333333333334

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7291666666666666

# %%
best_clf = best_estimators['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 7,  0,  1,  4,  0],
#        [ 0,  7,  0,  2,  0],
#        [ 1,  1,  3,  0,  1],
#        [ 1,  0,  0,  6,  0],
#        [ 0,  0,  1,  1, 12]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'marco_reus': 0,
#  'mason_mount': 1,
#  'ronaldo': 2,
#  'sergio_ramos': 3,
#  'toni_kroos': 4}

# %% [markdown]
# Save The Model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\ac\anaconda3\lib\site-packages (1.0.1)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
